# %%
# 1. Read the csv file.

import pandas as pd

df = pd.read_csv('customer_data.csv')

# %%
# 2. View the first 5 rows of the dataset to understand its structure.

df.head()
# Out:
#   prefix    first       last              email  gender  age  \
# 0    Dr.      Ray     Morton    sebvajom@kol.km    Male   38
# 1   Miss  Claudia  Rodriquez      acu@jatsot.ug  Female   51
# 2   Miss    Harry      Meyer          zuz@lo.wf  Female   51
# 3   Miss    Edith    Gilbert  hansohsi@jupec.md  Female   55
# 4    Dr.     Lura     Murphy     webediti@je.st  Female   20
#
#                         company              profession           phone  \
# 0                Medtronic Inc.        Health Therapist  (987) 619-2695
# 1  Ames Department Stores, Inc.        Health Therapist  (356) 736-7352
# 2                     CSX Corp.     Political Scientist  (539) 246-1806
# 3        Murphy Oil Corporation  Transportation Manager  (984) 962-7494
# 4                  PETsMART Inc            Statistician  (902) 568-9748
#
#     postal province             cc_no   cc_exp                    cc_type  \
# 0  B6V 3W3       MB  5020000000000230  05/2018                       Solo
# 1  G7M 5F3       SK  5020000000000230  07/2028                       Visa
# 2  A0Z 6P9       NS  6300000000000000  02/2023                     Switch
# 3  P9I 9H3       YT  3530000000000000  02/2028                    Maestro
# 4  S1A 6K0       ON  4030000000000000  10/2025  Diners Club International
#
#    price(CAD) fav_color              ip    weekday ampm        date
# 0        8.36      Blue    126.23.139.2     Sunday   pm  04/05/1930
# 1       68.31     Black  106.198.76.211    Tuesday   am  12/20/1926
# 2       34.65     Black  186.150.187.29  Wednesday   pm  08/20/1931
# 3       64.59     White   80.140.57.161   Saturday   am  06/18/2001
# 4       20.83    Yellow   211.103.43.41     Friday   pm  06/14/2045

# %%
# 3. How many rows and columns are in the dataset?

df.shape
    # 30000 rows 
    # 20 cols
# Out:
# (30000, 20)

# %%
# 4. Find the maximum, minimum, and mean age of the customers.

age_col = df['age']
max_age = age_col.max()
min_age = age_col.min()
mean_age = age_col.mean()

print(max_age)
print(min_age)
print(mean_age)
# Out:
# 65
# 18
# 41.550066666666666

# %%
# 5. What are the three most common customer names?

df['name'] = df['first'] + ' ' + df['last']
name_col = df['name']
name_col.value_counts().sort_values(ascending=False)[:3]
# Out:
# name
# Mr. Callie McCormick    3
# Mrs. Pauline Bowers     3
# Mr. Francis Hill        2
# Name: count, dtype: int64

# %%
# 6. Identify the customers who have the same phone number.?

same_phn = df.groupby('phone').filter(lambda x: len(x)>1)
same_phn[['name', 'phone']]
# Out:
#                 name           phone
# 15  Mrs. Lilly Tyler  (263) 382-8004
# 16   Mrs. Peter Cain  (263) 382-8004

# %%
# 7. How many customers have the profession “Structural Engineer”?

struct_eng_count = df['profession'].value_counts()['Structural Engineer']
struct_eng_count
# Out:
# np.int64(87)

# %%
# 8. How many male customers are Structural Engineers?

len(df[(df['gender']=='Male') & (df['profession']=='Structural Engineer')])
# Out:
# 43

# %%
# 9. Find the female Structural Engineers from the province of Alberta (AB)

df[(df['gender']=='Female') & (df['profession']=='Structural Engineer') & (df['province']=='AB')]
# Out:
#       prefix first      last              email  gender  age  \
# 8858     Dr.   Roy   Stanley  apiunvo@ehasom.ir  Female   39
# 9058     Mr.  Lora   Kennedy    dennap@rabac.se  Female   51
# 24736   Mrs.  Nell  Richards          dob@me.ki  Female   18
# 29865   Mrs.   Don  McDaniel        naf@zudu.bj  Female   37
#
#                               company           profession           phone  \
# 8858       Cincinnati Financial Corp.  Structural Engineer  (876) 758-2929
# 9058              BJ Services Company  Structural Engineer  (305) 786-6959
# 24736    Telephone & Data Systems Inc  Structural Engineer  (262) 681-5018
# 29865  Anadarko Petroleum Corporation  Structural Engineer  (238) 789-2825
#
#         postal  ...             cc_no   cc_exp  \
# 8858   N5A 6L2  ...  6300000000000000  02/2022
# 9058   N3R 4B7  ...   201000000000000  06/2019
# 24736  N3Y 3G2  ...   347000000000000  07/2028
# 29865  B4A 8Q9  ...  5610000000000000  12/2022
#
#                                   cc_type price(CAD)  fav_color  \
# 8858                         InstaPayment      31.86        Red
# 9058   Diners Club United States & Canada      53.29      Black
# 24736                    American Express      76.28       Blue
# 29865                          Mastercard      62.71       Blue
#
#                     ip    weekday ampm        date                name
# 8858    165.249.159.57     Sunday   pm  12/25/1903     Dr. Roy Stanley
# 9058    42.216.243.206   Thursday   pm  06/06/2028    Mr. Lora Kennedy
# 24736     91.16.30.156  Wednesday   pm  07/14/1951  Mrs. Nell Richards
# 29865  162.233.117.142     Sunday   pm  11/03/1989   Mrs. Don McDaniel
#
# [4 rows x 21 columns]

# %%
# 10. What is the maximum, minimum, and average spending amount?

spending_col = df['price(CAD)']
max_spending = spending_col.max()
min_spending = spending_col.min()
mean_spending = spending_col.mean()

print(max_spending)
print(min_spending)
print(mean_spending)
# Out:
# 100.0
# 0.0
# 49.990775

# %%
# 11. Who did not spend anything? Company wants to send a deal to encourage the customer to buy stuff!

df[df['price(CAD)']==0]
# Out:
#       prefix  first   last           email  gender  age              company  \
# 5320     Dr.  Bruce  Bryan  ru@pubuspuh.cl    Male   59  Wal-Mart Stores Inc
# 10597   Mrs.  Flora  Clark      wad@me.com  Female   27         MetLife Inc.
#
#                 profession           phone   postal  ...            cc_no  \
# 5320   Engineer Technician  (709) 446-8317  H6H 3Y0  ...  201000000000000
# 10597      Cruise Director  (775) 373-6590  B2U 8K6  ...   30100000000000
#
#         cc_exp                    cc_type price(CAD)  fav_color  \
# 5320   04/2024                   Bankcard        0.0      White
# 10597  05/2020  Diners Club Carte Blanche        0.0        Red
#
#                   ip    weekday ampm        date              name
# 5320     82.70.62.64  Wednesday   am  12/11/1900   Dr. Bruce Bryan
# 10597  231.156.15.63   Thursday   pm  08/22/1904  Mrs. Flora Clark
#
# [2 rows x 21 columns]

# %%
# 12. As a loyalty reward, company wants to send thanks coupon to those who spent 100CAD or more, please find out the customers?

df[df['price(CAD)']>=100]
# Out:
#       prefix    first         last          email  gender  age  \
# 76      Mrs.  Gregory        Brown     hav@jek.gs  Female   31
# 21093   Mrs.     Cody  Christensen    get@jovu.ag    Male   28
# 24385   Miss   Lizzie        Dixon  goh@tuwjaz.gd  Female   38
#
#                          company              profession           phone  \
# 76           E*Trade Group, Inc.                Novelist  (625) 537-8923
# 21093        National City Corp.  Hospital Administrator  (261) 737-3292
# 24385  FleetBoston Financial Co.    Compensation Analyst  (989) 239-1752
#
#         postal  ...             cc_no   cc_exp   cc_type price(CAD)  \
# 76     X3S 4Q2  ...  6010000000000000  04/2018      Visa      100.0
# 21093  X0S 1O5  ...   201000000000000  03/2024       JCB      100.0
# 24385  V8X 9V6  ...  6300000000000000  07/2019  Bankcard      100.0
#
#        fav_color             ip    weekday ampm        date  \
# 76         Green  212.100.18.95     Monday   am  10/23/2063
# 21093      Green  168.48.19.165  Wednesday   pm  03/28/1955
# 24385       Blue   140.87.99.78   Saturday   pm  03/03/1983
#
#                         name
# 76        Mrs. Gregory Brown
# 21093  Mrs. Cody Christensen
# 24385      Miss Lizzie Dixon
#
# [3 rows x 21 columns]

# %%
# 13. How many emails are associated with this credit card number ‘5020000000000230’?

df['email'][df['cc_no'] == 5020000000000230]
# Out:
# 0    sebvajom@kol.km
# 1      acu@jatsot.ug
# Name: email, dtype: object

# %%
# 14. We need to send new cards to the customers well before the expire, how many cards are expiring in 2019?

df['cc_exp_dt'] = pd.to_datetime(
    df['cc_exp'],
    format='%m/%Y',
    errors='coerce'
)
df[df['cc_exp_dt'].dt.year == 2019]
# Out:
#       prefix     first       last              email  gender  age  \
# 45      Mrs.  Winifred  Henderson     ezamaw@radi.kn  Female   43
# 46      Miss   Carolyn     Horton   dehje@mowakbo.tj    Male   22
# 49      Miss    Virgie      Adams   lodbinogu@ir.edu    Male   56
# 60      Mrs.     Blake       Hart         nup@pov.nc  Female   46
# 66      Miss     Leila  Carpenter       ke@wufiol.wf    Male   21
# ...      ...       ...        ...                ...     ...  ...
# 29952    Mr.     Julia    Elliott  zuruhmu@gevbon.th  Female   18
# 29957   Mrs.    Ronald   Stephens          beg@be.sc  Female   29
# 29959   Mrs.     Isaac   Guerrero        ji@rofom.ve    Male   21
# 29966   Mrs.    Hunter  Rodriguez      zubibil@fo.do  Female   26
# 29987    Mr.     Billy      Lucas     hihdu@kuwze.hm  Female   38
#
#                                 company                          profession  \
# 45                  Western Digital Inc                  Relocation Manager
# 46     Stewart & Stevenson Services Inc                    Employment Agent
# 49                   Maxtor Corporation                  Systems Programmer
# 60              Kindred Healthcare Inc.        Computer Graphics Specialist
# 66                    W.W. Grainger Inc                              Artist
# ...                                 ...                                 ...
# 29952      Gentiva Health Services Inc.               Management Consultant
# 29957            McDonald's Corporation                           Geologist
# 29959             Johnson Controls Inc.                              Lawyer
# 29966                    Pharmacia Corp                  Interior Decorator
# 29987                Deluxe Corporation  Organizational Development Manager
#
#                 phone   postal  ...                    cc_type  price(CAD)  \
# 45     (250) 572-7482  K9C 2D2  ...                      Laser       99.49
# 46     (737) 647-5446  L1F 9E3  ...               InstaPayment       44.46
# 49     (764) 601-4889  B2O 6Z0  ...  Diners Club Carte Blanche       66.05
# 60     (719) 605-1004  X0O 5E1  ...               InstaPayment       89.87
# 66     (816) 775-3467  E5X 5V9  ...              Visa Electron       29.63
# ...               ...      ...  ...                        ...         ...
# 29952  (878) 729-1214  C6L 3S8  ...  Diners Club International       42.49
# 29957  (937) 288-1029  V4W 1T1  ...              Discover Card       17.32
# 29959  (706) 297-1902  B9M 1U5  ...        Diners Club enRoute       26.69
# 29966  (874) 494-4542  K1M 8T0  ...               InstaPayment       62.58
# 29987  (933) 517-6356  K6I 2U5  ...               InstaPayment       21.17
#
#       fav_color               ip    weekday ampm        date  \
# 45         Blue    196.43.87.187  Wednesday   pm  07/21/2051
# 46       Yellow  135.153.126.179  Wednesday   pm  07/25/2010
# 49          Red  175.149.148.141     Monday   am  05/15/2047
# 60        White   164.16.206.229     Sunday   am  05/05/1942
# 66        Green   99.203.101.232    Tuesday   am  01/28/1936
# ...         ...              ...        ...  ...         ...
# 29952      Blue    42.62.136.183   Saturday   am  10/17/2063
# 29957       Red    46.127.70.118     Monday   pm  12/05/1913
# 29959     White   207.217.50.132     Monday   pm  01/25/1958
# 29966     Green   108.20.175.201    Tuesday   am  09/10/1918
# 29987      Blue       72.8.98.51    Tuesday   pm  05/18/1929
#
#                           name cc_expire_dt  cc_exp_dt
# 45     Mrs. Winifred Henderson   2019-12-01 2019-12-01
# 46         Miss Carolyn Horton   2019-07-01 2019-07-01
# 49           Miss Virgie Adams   2019-02-01 2019-02-01
# 60             Mrs. Blake Hart   2019-10-01 2019-10-01
# 66        Miss Leila Carpenter   2019-11-01 2019-11-01
# ...                        ...          ...        ...
# 29952        Mr. Julia Elliott   2019-05-01 2019-05-01
# 29957     Mrs. Ronald Stephens   2019-06-01 2019-06-01
# 29959      Mrs. Isaac Guerrero   2019-10-01 2019-10-01
# 29966    Mrs. Hunter Rodriguez   2019-09-01 2019-09-01
# 29987          Mr. Billy Lucas   2019-03-01 2019-03-01
#
# [2684 rows x 23 columns]

# %%
# 15. How many people use Visa as their Credit Card Provider?

len(df[df['cc_type']=='Visa'])
# Out:
# 1721

# %%
# 16. Can you find the customer who spent 100 CAD using Visa?

df[(df['cc_type']=='Visa') & (df['price(CAD)'] == 100)]
# Out:
#    prefix    first   last       email  gender  age              company  \
# 76   Mrs.  Gregory  Brown  hav@jek.gs  Female   31  E*Trade Group, Inc.
#
#    profession           phone   postal  ... cc_type  price(CAD) fav_color  \
# 76   Novelist  (625) 537-8923  X3S 4Q2  ...    Visa       100.0     Green
#
#                ip  weekday ampm        date                name cc_expire_dt  \
# 76  212.100.18.95   Monday   am  10/23/2063  Mrs. Gregory Brown   2018-04-01
#
#     cc_exp_dt
# 76 2018-04-01
#
# [1 rows x 23 columns]

# %%
# 17. What are two most common professions?

df['profession'].value_counts(ascending=False)[:2]
# Out:
# profession
# Preschool Teacher       112
# Distribution Manager    107
# Name: count, dtype: int64

# %%
# 18. Can you tell the top 5 most popular email providers? (e.g. gmail.com, yahoo.com, etc…)

df['email_provider'] = df['email'].str.split('@').str[1]
df['email_provider'].value_counts(ascending=False)[:5]
# Out:
# email_provider
# gmail.com      1687
# me.com         1676
# outlook.com    1664
# live.com       1660
# hotmail.com    1659
# Name: count, dtype: int64

# %%
# 19. Is there any customer who is using email with “am.edu”?

df[df['email_provider']=='am.edu']
# Out:
#     prefix    first      last         email  gender  age  \
# 150   Miss  Loretta  Fletcher  barit@am.edu  Female   48
#
#                      company                profession           phone  \
# 150  York International Corp  Rehabilitation Counselor  (323) 279-8038
#
#       postal  ... price(CAD)  fav_color              ip weekday  ampm  \
# 150  E5X 8L0  ...      97.26      White  147.57.240.225  Monday    am
#
#            date                   name cc_expire_dt  cc_exp_dt email_provider
# 150  11/07/2066  Miss Loretta Fletcher   2021-05-01 2021-05-01         am.edu
#
# [1 rows x 24 columns]

# %%
# 20. Which day of the week, the store gets more customers?

df.groupby('weekday')['name'].count().sort_values(ascending=False).idxmax()
# Out:
# 'Saturday'
